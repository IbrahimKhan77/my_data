# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimKhan77/my_data/blob/main/main_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !git clone https://github.com/IbrahimKhan77/my_data.git
# Out:
# Cloning into 'my_data'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
df = pd.read_excel("/content/my_data/Survey_Data.xlsx")
df
# Out:
#      Gender Mode of study Year of study  \
# 0      Male     Full-time             3
# 1      Male     Full-time             3
# 2    Female     Full-time             3
# 3      Male     Full-time             3
# 4    Female     Full-time             3
# ..      ...           ...           ...
# 420  Female     Full-time             3
# 421    Male     Full-time             1
# 422  Female     Full-time             3
# 423  Female     Full-time             1
# 424    Male     Full-time             1
#
#     Do you have reliable access to wi-fi at home?  \
# 0                                             Yes
# 1                                             Yes
# 2                                             Yes
# 3                                             Yes
# 4                                             Yes
# ..                                            ...
# 420                                           Yes
# 421                                           Yes
# ...
